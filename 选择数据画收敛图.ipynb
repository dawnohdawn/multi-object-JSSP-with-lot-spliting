# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

PATH = os.path.abspath('.') + '\\modifiedGAModels\\convergeData'

# %% [markdown]
# ##  originalMBO和originalMBO_newNeighbours的收敛对比

# %%
def plotmbo(file1, file2):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
    data2 = pd.read_csv(PATH+"\\" + file2, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({'MBO':data1.originalMBO,'MBO+nei':data2.originalMBO_newNeighbours})
    #画图
    mixdata.plot()

# %%
# P1的理想图形
plotmbo('OMBO & OMBO+NEI-P1-87-90.csv', 'OMBO+NEI-P1-85.csv')
plt.savefig(PATH+"\\"+'MBO & MBO+nei 收敛对比-P1',dpi=160)

plt.xlabel(u'迭代')

# 表现出收敛速度了
# Out:
# Text(0.5,15,'迭代')

# %%
# P2的理想图形
plotmbo('OMBO & OMBO+NEI-P2-188-184.csv', 'OMBO & OMBO+NEI-P2-188-184.csv')
plt.savefig(PATH+"\\"+'MBO & MBO+nei 收敛对比-P2',dpi=160)

# 表现出跳出局部最优了

# %%
# P3的理想图形
plotmbo('OMBO-P3-198.csv', 'OMBO+NEI-P3-197.csv')
plt.savefig(PATH+"\\"+'MBO & MBO+nei 收敛对比-P3',dpi=160)

# %%
# P4的理想图形
plotmbo('OMBO-P4-387.csv', 'OMBO+NEI-P4-386.csv')
plt.savefig(PATH+"\\"+'MBO & MBO+nei 收敛对比-P4',dpi=160)

# %% [markdown]
# ##  originalMBO和myMBO1（不加aging）的收敛对比

# %%
def plotmbo(file1, file2):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
    data2 = pd.read_csv(PATH+"\\" + file2, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({'MBO':data1.originalMBO,'myMBO1':data2.myMBO1})
    #画图
    mixdata.plot()

# %%
# P1的理想图形
plotmbo('MBO & myMBO1-P1-85-85.csv', 'myMBO1-P1-85.csv')
plt.savefig(PATH+"\\"+'MBO & myMBO1 收敛对比-P1',dpi=160)

# %%
# P2的理想图形
plotmbo('MBO & myMBO1-P2-193-187.csv', 'MBO & myMBO1-P2-193-187.csv')
plt.savefig(PATH+"\\"+'MBO & myMBO1 收敛对比-P2',dpi=160)

# %%
# P3的理想图形
plotmbo('MBO & myMBO1-P3-204-198.csv', 'MBO & myMBO1-P3-204-198.csv')
plt.savefig(PATH+"\\"+'MBO & myMBO1 收敛对比-P3',dpi=160)

# %%
# P4的理想图形
plotmbo('MBO & myMBO1-P4-385-378.csv', 'MBO & myMBO1-P4-385-378.csv')
plt.savefig(PATH+"\\"+'MBO & myMBO1 收敛对比-P4',dpi=160)

# %% [markdown]
# ##  originalMBO和myMBO1+aging的收敛对比

# %%
def plotmbo(file1, file2):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
    data2 = pd.read_csv(PATH+"\\" + file2, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({'MBO':data1.originalMBO,'myMBO1+aging':data2.myMBO1})
    #画图
    mixdata.plot()
#     mixdata.plot(grid=False, style=['k:', 'k-', 'k--'], legend=True, figsize=(5,3.5))

# %%
# P1的理想图形
plotmbo('MBO & myMBO1+aging-P1-86-85.csv', 'myMBO1+aging-P1-85.csv')
plt.savefig(PATH+"\\"+'myMBO1+aging收敛对比-P1',dpi=160)

# %%
# P2的理想图形
plotmbo('MBO & myMBO1+aging-P2-193-185.csv', 'MBO & myMBO1+aging-P2-193-185.csv')
plt.savefig(PATH+"\\"+'myMBO1+aging收敛对比-P2',dpi=160)

# %%
# P3的理想图形
plotmbo('MBO & myMBO1+aging-P3-203-192.csv', 'MBO & myMBO1+aging-P3-203-192.csv')
plt.savefig(PATH+"\\"+'myMBO1+aging收敛对比-P3',dpi=160)

# %%
# P4的理想图形
plotmbo('MBO & myMBO1+aging-P4-380-376.csv', 'myMBO1-P4-371.csv')
plt.savefig(PATH+"\\"+'myMBO1+aging收敛对比-P4',dpi=160)

# %% [markdown]
# ##  originalMBO和myMBO1和myMBO1+aging的收敛对比

# %%
def plotmbo(file1, file2, file3):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
    data2 = pd.read_csv(PATH+"\\" + file2, header=0)
    data3 = pd.read_csv(PATH+"\\" + file3, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({'MBO':data1.originalMBO,'myMBO1':data2.myMBO1,'myMBO1+aging':data3.myMBO1})
    #画图
    mixdata.plot()

# %%
# P1的理想图形
plotmbo('MBO & myMBO1+aging-P1-86-85.csv','myMBO1-P1-85.csv', 'myMBO1+aging-P1-85.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'MBO & myMBO & myMBO1+aging 收敛对比-P1',dpi=160)

# %%
# P2的理想图形
plotmbo('MBO & myMBO1+aging-P2-193-185.csv','MBO & myMBO1-P2-193-187.csv', 'MBO & myMBO1+aging-P2-193-185.csv')
plt.savefig(PATH+"\\"+'MBO & myMBO & myMBO1+aging 收敛对比-P2',dpi=160)

# %%
# P3的理想图形
plotmbo('MBO & myMBO1+aging-P3-203-192.csv','MBO & myMBO1-P3-204-198.csv', 'MBO & myMBO1+aging-P3-203-192.csv')
plt.savefig(PATH+"\\"+'MBO & myMBO & myMBO1+aging 收敛对比-P3',dpi=160)

# %%
# P4的理想图形
plotmbo('MBO & myMBO1+aging-P4-380-376.csv','myMBO1-P4-378.csv', 'myMBO1-P4-371.csv')  # MBO & myMBO1-P4-385-378
plt.savefig(PATH+"\\"+'MBO & myMBO & myMBO1+aging 收敛对比-P4',dpi=160)

# %% [markdown]
# ## 多种群算法对比

# %%
def plotmbo(file1, file2, file3, file4):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
    data2 = pd.read_csv(PATH+"\\" + file2, header=0)
    data3 = pd.read_csv(PATH+"\\" + file3, header=0)
    data4 = pd.read_csv(PATH+"\\" + file4, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({'ML-CCMBO':data1.myPMBO1,'PCCMBO+stage':data2.myPMBO1,'PCCMBO+diff':data3.myPMBO1,'PCCMBO':data4.myPMBO1})
    #画图
#     mixdata.plot(grid=False, style=['k-', 'k:', 'k--', 'k-.'], legend=True, figsize=(5,3.5))
    mixdata.plot(grid=False, style=['m-', 'k:', 'g--', 'b-.'], legend=True, figsize=(4.5,3.5), fontsize=12)
    plt.xlabel('iterration', fontsize=12)
    plt.ylabel('makespan', fontsize=12)
#     x = np.linspace(0, 1000, 1000)
#     fig, ax = plt.subplots()
#     plt.grid()
#     line1, = ax.plot(x, list(mixdata.iloc[:,0]), '-.', linewidth=2, label=mixdata.columns.values.tolist()[0])
#     line2, = ax.plot(x, list(mixdata.iloc[:,1]), ':', linewidth=2, label=mixdata.columns.values.tolist()[1])
#     line3, = ax.plot(x, list(mixdata.iloc[:,2]), '-', linewidth=2, label=mixdata.columns.values.tolist()[2])
#     line4, = ax.plot(x, list(mixdata.iloc[:,3]), '--', linewidth=2, label=mixdata.columns.values.tolist()[3])
#     ax.legend()  
#     plt.show()

# %%
# P1的理想图形
plotmbo('MLCCMBO-P1-83.csv','PCCMBO+stage-P1-85.csv', 'PCCMBO+diff-P1-85.csv', 'PCCMBO-P1-85(3).csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PCCMBO+stage & PCCMBO+diff & PCCMBO收敛对比-P1',dpi=160)

# %%
# P2的理想图形
plotmbo('MLCCMBO-P2-183.csv','PCCMBO+stage-P2-185.csv', 'PCCMBO+diff-P2-186.csv', 'PCCMBO-P2-188.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PCCMBO+stage & PCCMBO+diff & PCCMBO收敛对比-P2',dpi=160)

# %%
# P3的理想图形
plotmbo('MLCCMBO-P3-192.csv','PCCMBO+stage-P3-195.csv', 'PCCMBO+diff-P3-196.csv', 'PCCMBO-P3-195.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PCCMBO+stage & PCCMBO+diff & PCCMBO收敛对比-P3',dpi=160)

# %%
# P4的理想图形
plotmbo('MLCCMBO-P4-371.csv','PCCMBO+stage-P4-374.csv', 'PCCMBO+diff-P4-376.csv', 'PCCMBO-P4-376.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PCCMBO+stage & PCCMBO+diff & PCCMBO收敛对比-P4',dpi=160)

# %%
def plotmbo(file1):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
#     data2 = pd.read_csv(PATH+"\\" + file2, header=0)
#     data3 = pd.read_csv(PATH+"\\" + file3, header=0)
#     data4 = pd.read_csv(PATH+"\\" + file4, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({'ML-CCMBO':data1.MLCCMBO,'PCCMBO+stage':data1.PCCMBOstage,'PCCMBO+diff':data1.PCCMBOdiff,'PCCMBO':data1.PCCMBO})
    #画图
    mixdata.plot(grid=False, style=['k-', 'k:', 'k--', 'k-.'], legend=True, figsize=(5,3.5))

# %%
# P5的理想图形
plotmbo('ML-CCMBO-P5-128.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PCCMBO+stage & PCCMBO+diff & PCCMBO收敛对比-P5',dpi=160)

# %% [markdown]
# ## 单多种群对比1

# %%
def plotmbo(file1, file2, file3):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
    data2 = pd.read_csv(PATH+"\\" + file2, header=0)
    data3 = pd.read_csv(PATH+"\\" + file3, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({'ML-CCMBO':data1.myPMBO1, 'PCCMBO':data2.myPMBO1, 'CCMBO':data3.myMBO1})
    #画图
    mixdata.plot(grid=False, style=['k:', 'k-', 'k--'], legend=True, figsize=(5,3.5))

# %%
# P1的理想图形
plotmbo('MLCCMBO-P1-83.csv', 'PCCMBO-P1-85(3).csv', 'CCMBO-P1-85.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PCCMBO & CCMBO收敛对比-P1',dpi=160)

# %%
# P2的理想图形
plotmbo('MLCCMBO-P2-183.csv', 'PCCMBO-P2-188.csv', 'CCMBO-P2-188.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PCCMBO & CCMBO收敛对比-P2',dpi=160)

# %%
# P3的理想图形
plotmbo('MLCCMBO-P3-192.csv', 'PCCMBO-P3-195.csv', 'CCMBO-P3-195.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PCCMBO & CCMBO收敛对比-P3',dpi=160)

# %%
# P4的理想图形
plotmbo('MLCCMBO-P4-371.csv', 'PCCMBO-P4-376.csv', 'CCMBO-P4-378.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PCCMBO & CCMBO收敛对比-P4',dpi=160)

# %% [markdown]
# ## 单多种群对比2

# %%
import matplotlib.pyplot as plt
plt.rc('font',family='Times New Roman')

# %%
def plotmbo(file1, file2, file3):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
    data2 = pd.read_csv(PATH+"\\" + file2, header=0)
    data3 = pd.read_csv(PATH+"\\" + file3, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({'ML-CCMBO':data1.myPMBO1, 'PMBO':data2.PMBO1, 'MBO':data3.originalMBO})
    #画图
#     mixdata.plot(grid=False, style=['k:', 'k-', 'k--'], legend=True, figsize=(5,3.5))
    mixdata.plot(grid=False, style=['k:', 'm-', 'b--', 'b-.'], legend=True, figsize=(4.5,3.5), fontsize=12)
    plt.xlabel('$iteration$', fontsize=12)
    plt.ylabel('$makespan$', fontsize=12)

# %%
# P1的理想图形
plotmbo('MLCCMBO-P1-83.csv', 'PMBO-P1-85.csv', 'MBO & myMBO1+aging-P1-86-85.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PMBO & MBO收敛对比-P1',dpi=160)

# %%
# P2的理想图形
plotmbo('MLCCMBO-P2-183.csv', 'PMBO-P2-186.csv', 'OMBO & OMBO+NEI-P2-188-184.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PMBO & MBO收敛对比-P2',dpi=160)

# %%
# P3的理想图形
plotmbo('MLCCMBO-P3-192.csv', 'PMBO-P3-200.csv', 'MBO & myMBO1-P3-204-198.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PMBO & MBO收敛对比-P3',dpi=160)

# %%
# P4的理想图形
plotmbo('MLCCMBO-P4-371.csv', 'PMBO-P4-380.csv', 'MBO & myMBO1-P4-385-378.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+'ML-CCMBO & PMBO & MBO收敛对比-P4',dpi=160)

# %%
def plotmbo(file1, file2):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
    data2 = pd.read_csv(PATH+"\\" + file2, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({"algotirhm1":data1.myPMBO1, 'algorithm2':data2.myPMBO1})
    #画图
#     mixdata.plot()
#     mixdata.plot(grid=False, style=['k--', 'k-'], legend=True, figsize=(6,4.5))
    mixdata.plot(grid=False, style=['k:', 'k-', 'b--', 'b-.'], legend=True, figsize=(6,4), fontsize=12)
    plt.xlabel('iter')
    plt.ylabel('makespan')
    plt.xlabel('iterration', fontsize=12)
    plt.ylabel('makespan', fontsize=12)
    
# 
plotmbo('MLCCMBO-P2-183.csv', 'PCCMBO-P2-188.csv')  # MBO & myMBO1-P1-85-85
plt.savefig(PATH+"\\"+"停滞示意图",dpi=160)

# %% [markdown]
# ## 单种群改进对比

# %%
import matplotlib.pyplot as plt
plt.rc('font',family='Times New Roman')

# %%
def plotmbo(file1):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({'MBO+improvedV':data1.MBOimprovedV, 'MBO+adjust':data1.MBOadjust, \
                            'MBO+compete':data1.MBOcompete, 'MBO':data1.MBO})
    #画图
    mixdata.plot(grid=False, style=['k:', 'm-', 'g--', 'b-.'], legend=True, figsize=(4.5,3.5), fontsize=12)
    plt.xlabel('iterration', fontsize=12)
    plt.ylabel('makespan', fontsize=12)

# %%
#p1
plotmbo('MBO & MBO+improvedV & MBO+compete & MBO+adjust-P1.csv')
plt.savefig(PATH+"\\"+'MBO & MBO+improvedV & MBO+compete & MBO+adjust收敛对比-P1',dpi=160)
# plt.savefig(PATH+"\\"+'MBO & MBO+improvedV & MBO+compete & MBO+adjust收敛对比-P1')

# %%
#p2
plotmbo('MBO & MBO+improvedV & MBO+compete & MBO+adjust-P2.csv')
plt.savefig(PATH+"\\"+'MBO & MBO+improvedV & MBO+compete & MBO+adjust收敛对比-P2',dpi=160)

# %%
#p3
plotmbo('MBO & MBO+improvedV & MBO+compete & MBO+adjust-P3.csv')
plt.savefig(PATH+"\\"+'MBO & MBO+improvedV & MBO+compete & MBO+adjust收敛对比-P3',dpi=160)

# %%
#p4
plotmbo('MBO & MBO+improvedV & MBO+compete & MBO+adjust-P4.csv')
plt.savefig(PATH+"\\"+'MBO & MBO+improvedV & MBO+compete & MBO+adjust收敛对比-P4',dpi=160)

# %% [markdown]
# ## 单种群对比2

# %%
def plotmbo(file1):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({'CCMBO':data1.CCMBO, 'MBO':data1.MBO})
    #画图
#     mixdata.plot(grid=False, style=['k-', 'k--'], legend=True, figsize=(5,3.5))
    mixdata.plot(grid=False, style=['b-', 'k--'], legend=True, figsize=(4.5,3.5), fontsize=12)
    plt.xlabel('iterration', fontsize=12)
    plt.ylabel('makespan', fontsize=12)

# %%
#p1
plotmbo('MBO & MBO+improvedV & MBO+compete & MBO+adjust-P1.csv')
plt.savefig(PATH+"\\"+'MBO & CCMBO收敛对比-P1',dpi=160)

# %%
#p2
plotmbo('MBO & MBO+improvedV & MBO+compete & MBO+adjust-P2.csv')
plt.savefig(PATH+"\\"+'MBO & CCMBO收敛对比-P2',dpi=160)

# %%
#p3
plotmbo('MBO & MBO+improvedV & MBO+compete & MBO+adjust-P3.csv')
plt.savefig(PATH+"\\"+'MBO & CCMBO收敛对比-P3',dpi=160)

# %%
#p4
plotmbo('MBO & MBO+improvedV & MBO+compete & MBO+adjust-P4.csv')
plt.savefig(PATH+"\\"+'MBO & CCMBO收敛对比-P4',dpi=160)

# %%
def plotmbo(file1):
    """
    功能：
    取data1的originalMBO，取data2的originalMBO_newNeighbours，画收敛曲线
    
    输入：
    file1，file2    要用到的csv文件全名
    """ 
    # 提取csv，取data1的originalMBO，取data2的originalMBO_newNeighbours
    data1 = pd.read_csv(PATH+"\\" + file1, header=0)
    # 混合需要的数据，在此可更改两个算法的名字
    mixdata = pd.DataFrame({'CCMBO':data1.CCMBO, 'MBO+improvedV':data2.MBOimprovedV, 'MBO+adjust':data3.MBOadjust, \
                            'MBO+compete':data4.MBOcompete, 'MBO':data4.MBO})
    #画图
    mixdata.plot(grid=False, style=['k-', 'k:', 'k--', 'k-.'], legend=True, figsize=(5,3.5))
